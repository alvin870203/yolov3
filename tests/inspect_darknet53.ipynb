# %% [markdown]
# # Inspect Darknet53 Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
from torchinfo import summary
import sys
sys.path.append('../')
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# ## Inspect Structure & In/Out Shape

# %%
from models.darknet53 import Darknet53Config, Darknet53

img_h, img_w, n_class = 256, 256, 1000
model_args = dict(
    img_h=img_h,
    img_w=img_w,
    n_class=n_class
)

model_config = Darknet53Config(**model_args)
model = Darknet53(model_config)

batch_size = 1
summary(model, input_size=[(batch_size, 3, img_h, img_w)], device='cpu',
        col_names=("input_size", "output_size", "num_params", "kernel_size", "mult_adds", "trainable"), verbose=2,
        depth=4, row_settings=("depth", "var_names"));
# Out:
# number of parameters: 41.61M
# ========================================================================================================================================================================================================
# Layer (type (var_name):depth-idx)                  Input Shape               Output Shape              Param #                   Kernel Shape              Mult-Adds                 Trainable
# ========================================================================================================================================================================================================
# Darknet53 (Darknet53)                              [1, 3, 256, 256]          [1, 1000]                 --                        --                        --                        True
# ├─Darknet53Backbone (backbone): 1-1                [1, 3, 256, 256]          [1, 1024, 8, 8]           --                        --                        --                        True
# │    └─conv0.conv.weight                                                                               ├─864                     [32, 3, 3, 3]
# │    └─conv0.bn.weight                                                                                 ├─32                      [32]
# │    └─conv0.bn.bias                                                                                   ├─32                      [32]
# │    └─conv1.conv.weight                                                                               ├─18,432                  [64, 32, 3, 3]
# │    └─conv1.bn.weight                                                                                 ├─64                      [64]
# │    └─conv1.bn.bias                                                                                   ├─64                      [64]
# │    └─stage1_block1.conv1x1.conv.weight                                                               ├─2,048                   [32, 64, 1, 1]
# │    └─stage1_block1.conv1x1.bn.weight                                                                 ├─32                      [32]
# │    └─stage1_block1.conv1x1.bn.bias                                                                   ├─32                      [32]
# │    └─stage1_block1.conv3x3.conv.weight                                                               ├─18,432                  [64, 32, 3, 3]
# │    └─stage1_block1.conv3x3.bn.weight                                                                 ├─64                      [64]
# │    └─stage1_block1.conv3x3.bn.bias                                                                   ├─64                      [64]
# │    └─conv2.conv.weight                                                                               ├─73,728                  [128, 64, 3, 3]
# │    └─conv2.bn.weight                                                                                 ├─128                     [128]
# │    └─conv2.bn.bias                                                                                   ├─128                     [128]
# │    └─stage2_block1.conv1x1.conv.weight                                                               ├─8,192                   [64, 128, 1, 1]
# │    └─stage2_block1.conv1x1.bn.weight                                                                 ├─64                      [64]
# │    └─stage2_block1.conv1x1.bn.bias                                                                   ├─64                      [64]
# │    └─stage2_block1.conv3x3.conv.weight                                                               ├─73,728                  [128, 64, 3, 3]
# │    └─stage2_block1.conv3x3.bn.weight                                                                 ├─128                     [128]
# │    └─stage2_block1.conv3x3.bn.bias                                                                   ├─128                     [128]
# │    └─stage2_block2.conv1x1.conv.weight                                                               ├─8,192                   [64, 128, 1, 1]
# │    └─stage2_block2.conv1x1.bn.weight                                                                 ├─64                      [64]
# │    └─stage2_block2.conv1x1.bn.bias                                                                   ├─64                      [64]
# │    └─stage2_block2.conv3x3.conv.weight                                                               ├─73,728                  [128, 64, 3, 3]
# │    └─stage2_block2.conv3x3.bn.weight                                                                 ├─128                     [128]
# │    └─stage2_block2.conv3x3.bn.bias                                                                   ├─128                     [128]
# │    └─conv3.conv.weight                                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─conv3.bn.weight                                                                                 ├─256                     [256]
# │    └─conv3.bn.bias                                                                                   ├─256                     [256]
# │    └─stage3_block1.conv1x1.conv.weight                                                               ├─32,768                  [128, 256, 1, 1]
# │    └─stage3_block1.conv1x1.bn.weight                                                                 ├─128                     [128]
# │    └─stage3_block1.conv1x1.bn.bias                                                                   ├─128                     [128]
# │    └─stage3_block1.conv3x3.conv.weight                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─stage3_block1.conv3x3.bn.weight                                                                 ├─256                     [256]
# │    └─stage3_block1.conv3x3.bn.bias                                                                   ├─256                     [256]
# │    └─stage3_block2.conv1x1.conv.weight                                                               ├─32,768                  [128, 256, 1, 1]
# │    └─stage3_block2.conv1x1.bn.weight                                                                 ├─128                     [128]
# │    └─stage3_block2.conv1x1.bn.bias                                                                   ├─128                     [128]
# │    └─stage3_block2.conv3x3.conv.weight                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─stage3_block2.conv3x3.bn.weight                                                                 ├─256                     [256]
# │    └─stage3_block2.conv3x3.bn.bias                                                                   ├─256                     [256]
# │    └─stage3_block3.conv1x1.conv.weight                                                               ├─32,768                  [128, 256, 1, 1]
# │    └─stage3_block3.conv1x1.bn.weight                                                                 ├─128                     [128]
# │    └─stage3_block3.conv1x1.bn.bias                                                                   ├─128                     [128]
# │    └─stage3_block3.conv3x3.conv.weight                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─stage3_block3.conv3x3.bn.weight                                                                 ├─256                     [256]
# │    └─stage3_block3.conv3x3.bn.bias                                                                   ├─256                     [256]
# │    └─stage3_block4.conv1x1.conv.weight                                                               ├─32,768                  [128, 256, 1, 1]
# │    └─stage3_block4.conv1x1.bn.weight                                                                 ├─128                     [128]
# │    └─stage3_block4.conv1x1.bn.bias                                                                   ├─128                     [128]
# │    └─stage3_block4.conv3x3.conv.weight                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─stage3_block4.conv3x3.bn.weight                                                                 ├─256                     [256]
# │    └─stage3_block4.conv3x3.bn.bias                                                                   ├─256                     [256]
# │    └─stage3_block5.conv1x1.conv.weight                                                               ├─32,768                  [128, 256, 1, 1]
# │    └─stage3_block5.conv1x1.bn.weight                                                                 ├─128                     [128]
# │    └─stage3_block5.conv1x1.bn.bias                                                                   ├─128                     [128]
# │    └─stage3_block5.conv3x3.conv.weight                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─stage3_block5.conv3x3.bn.weight                                                                 ├─256                     [256]
# │    └─stage3_block5.conv3x3.bn.bias                                                                   ├─256                     [256]
# │    └─stage3_block6.conv1x1.conv.weight                                                               ├─32,768                  [128, 256, 1, 1]
# │    └─stage3_block6.conv1x1.bn.weight                                                                 ├─128                     [128]
# │    └─stage3_block6.conv1x1.bn.bias                                                                   ├─128                     [128]
# │    └─stage3_block6.conv3x3.conv.weight                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─stage3_block6.conv3x3.bn.weight                                                                 ├─256                     [256]
# │    └─stage3_block6.conv3x3.bn.bias                                                                   ├─256                     [256]
# │    └─stage3_block7.conv1x1.conv.weight                                                               ├─32,768                  [128, 256, 1, 1]
# │    └─stage3_block7.conv1x1.bn.weight                                                                 ├─128                     [128]
# │    └─stage3_block7.conv1x1.bn.bias                                                                   ├─128                     [128]
# │    └─stage3_block7.conv3x3.conv.weight                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─stage3_block7.conv3x3.bn.weight                                                                 ├─256                     [256]
# │    └─stage3_block7.conv3x3.bn.bias                                                                   ├─256                     [256]
# │    └─stage3_block8.conv1x1.conv.weight                                                               ├─32,768                  [128, 256, 1, 1]
# │    └─stage3_block8.conv1x1.bn.weight                                                                 ├─128                     [128]
# │    └─stage3_block8.conv1x1.bn.bias                                                                   ├─128                     [128]
# │    └─stage3_block8.conv3x3.conv.weight                                                               ├─294,912                 [256, 128, 3, 3]
# │    └─stage3_block8.conv3x3.bn.weight                                                                 ├─256                     [256]
# │    └─stage3_block8.conv3x3.bn.bias                                                                   ├─256                     [256]
# │    └─conv4.conv.weight                                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─conv4.bn.weight                                                                                 ├─512                     [512]
# │    └─conv4.bn.bias                                                                                   ├─512                     [512]
# │    └─stage4_block1.conv1x1.conv.weight                                                               ├─131,072                 [256, 512, 1, 1]
# │    └─stage4_block1.conv1x1.bn.weight                                                                 ├─256                     [256]
# │    └─stage4_block1.conv1x1.bn.bias                                                                   ├─256                     [256]
# │    └─stage4_block1.conv3x3.conv.weight                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─stage4_block1.conv3x3.bn.weight                                                                 ├─512                     [512]
# │    └─stage4_block1.conv3x3.bn.bias                                                                   ├─512                     [512]
# │    └─stage4_block2.conv1x1.conv.weight                                                               ├─131,072                 [256, 512, 1, 1]
# │    └─stage4_block2.conv1x1.bn.weight                                                                 ├─256                     [256]
# │    └─stage4_block2.conv1x1.bn.bias                                                                   ├─256                     [256]
# │    └─stage4_block2.conv3x3.conv.weight                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─stage4_block2.conv3x3.bn.weight                                                                 ├─512                     [512]
# │    └─stage4_block2.conv3x3.bn.bias                                                                   ├─512                     [512]
# │    └─stage4_block3.conv1x1.conv.weight                                                               ├─131,072                 [256, 512, 1, 1]
# │    └─stage4_block3.conv1x1.bn.weight                                                                 ├─256                     [256]
# │    └─stage4_block3.conv1x1.bn.bias                                                                   ├─256                     [256]
# │    └─stage4_block3.conv3x3.conv.weight                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─stage4_block3.conv3x3.bn.weight                                                                 ├─512                     [512]
# │    └─stage4_block3.conv3x3.bn.bias                                                                   ├─512                     [512]
# │    └─stage4_block4.conv1x1.conv.weight                                                               ├─131,072                 [256, 512, 1, 1]
# │    └─stage4_block4.conv1x1.bn.weight                                                                 ├─256                     [256]
# │    └─stage4_block4.conv1x1.bn.bias                                                                   ├─256                     [256]
# │    └─stage4_block4.conv3x3.conv.weight                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─stage4_block4.conv3x3.bn.weight                                                                 ├─512                     [512]
# │    └─stage4_block4.conv3x3.bn.bias                                                                   ├─512                     [512]
# │    └─stage4_block5.conv1x1.conv.weight                                                               ├─131,072                 [256, 512, 1, 1]
# │    └─stage4_block5.conv1x1.bn.weight                                                                 ├─256                     [256]
# │    └─stage4_block5.conv1x1.bn.bias                                                                   ├─256                     [256]
# │    └─stage4_block5.conv3x3.conv.weight                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─stage4_block5.conv3x3.bn.weight                                                                 ├─512                     [512]
# │    └─stage4_block5.conv3x3.bn.bias                                                                   ├─512                     [512]
# │    └─stage4_block6.conv1x1.conv.weight                                                               ├─131,072                 [256, 512, 1, 1]
# │    └─stage4_block6.conv1x1.bn.weight                                                                 ├─256                     [256]
# │    └─stage4_block6.conv1x1.bn.bias                                                                   ├─256                     [256]
# │    └─stage4_block6.conv3x3.conv.weight                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─stage4_block6.conv3x3.bn.weight                                                                 ├─512                     [512]
# │    └─stage4_block6.conv3x3.bn.bias                                                                   ├─512                     [512]
# │    └─stage4_block7.conv1x1.conv.weight                                                               ├─131,072                 [256, 512, 1, 1]
# │    └─stage4_block7.conv1x1.bn.weight                                                                 ├─256                     [256]
# │    └─stage4_block7.conv1x1.bn.bias                                                                   ├─256                     [256]
# │    └─stage4_block7.conv3x3.conv.weight                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─stage4_block7.conv3x3.bn.weight                                                                 ├─512                     [512]
# │    └─stage4_block7.conv3x3.bn.bias                                                                   ├─512                     [512]
# │    └─stage4_block8.conv1x1.conv.weight                                                               ├─131,072                 [256, 512, 1, 1]
# │    └─stage4_block8.conv1x1.bn.weight                                                                 ├─256                     [256]
# │    └─stage4_block8.conv1x1.bn.bias                                                                   ├─256                     [256]
# │    └─stage4_block8.conv3x3.conv.weight                                                               ├─1,179,648               [512, 256, 3, 3]
# │    └─stage4_block8.conv3x3.bn.weight                                                                 ├─512                     [512]
# │    └─stage4_block8.conv3x3.bn.bias                                                                   ├─512                     [512]
# │    └─conv5.conv.weight                                                                               ├─4,718,592               [1024, 512, 3, 3]
# │    └─conv5.bn.weight                                                                                 ├─1,024                   [1024]
# │    └─conv5.bn.bias                                                                                   ├─1,024                   [1024]
# │    └─stage5_block1.conv1x1.conv.weight                                                               ├─524,288                 [512, 1024, 1, 1]
# │    └─stage5_block1.conv1x1.bn.weight                                                                 ├─512                     [512]
# │    └─stage5_block1.conv1x1.bn.bias                                                                   ├─512                     [512]
# │    └─stage5_block1.conv3x3.conv.weight                                                               ├─4,718,592               [1024, 512, 3, 3]
# │    └─stage5_block1.conv3x3.bn.weight                                                                 ├─1,024                   [1024]
# │    └─stage5_block1.conv3x3.bn.bias                                                                   ├─1,024                   [1024]
# │    └─stage5_block2.conv1x1.conv.weight                                                               ├─524,288                 [512, 1024, 1, 1]
# │    └─stage5_block2.conv1x1.bn.weight                                                                 ├─512                     [512]
# │    └─stage5_block2.conv1x1.bn.bias                                                                   ├─512                     [512]
# │    └─stage5_block2.conv3x3.conv.weight                                                               ├─4,718,592               [1024, 512, 3, 3]
# │    └─stage5_block2.conv3x3.bn.weight                                                                 ├─1,024                   [1024]
# │    └─stage5_block2.conv3x3.bn.bias                                                                   ├─1,024                   [1024]
# │    └─stage5_block3.conv1x1.conv.weight                                                               ├─524,288                 [512, 1024, 1, 1]
# │    └─stage5_block3.conv1x1.bn.weight                                                                 ├─512                     [512]
# │    └─stage5_block3.conv1x1.bn.bias                                                                   ├─512                     [512]
# │    └─stage5_block3.conv3x3.conv.weight                                                               ├─4,718,592               [1024, 512, 3, 3]
# │    └─stage5_block3.conv3x3.bn.weight                                                                 ├─1,024                   [1024]
# │    └─stage5_block3.conv3x3.bn.bias                                                                   ├─1,024                   [1024]
# │    └─stage5_block4.conv1x1.conv.weight                                                               ├─524,288                 [512, 1024, 1, 1]
# │    └─stage5_block4.conv1x1.bn.weight                                                                 ├─512                     [512]
# │    └─stage5_block4.conv1x1.bn.bias                                                                   ├─512                     [512]
# │    └─stage5_block4.conv3x3.conv.weight                                                               ├─4,718,592               [1024, 512, 3, 3]
# │    └─stage5_block4.conv3x3.bn.weight                                                                 ├─1,024                   [1024]
# │    └─stage5_block4.conv3x3.bn.bias                                                                   └─1,024                   [1024]
# │    └─Darknet53Conv2d (conv0): 2-1                [1, 3, 256, 256]          [1, 32, 256, 256]         --                        --                        --                        True
# │    │    └─conv.weight                                                                                ├─864                     [32, 3, 3, 3]
# │    │    └─bn.weight                                                                                  ├─32                      [32]
# │    │    └─bn.bias                                                                                    └─32                      [32]
# │    │    └─Conv2d (conv): 3-1                     [1, 3, 256, 256]          [1, 32, 256, 256]         864                       [3, 3]                    56,623,104                True
# │    │    │    └─weight                                                                                └─864                     [3, 32, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-2                  [1, 32, 256, 256]         [1, 32, 256, 256]         64                        --                        64                        True
# │    │    │    └─weight                                                                                ├─32                      [32]
# │    │    │    └─bias                                                                                  └─32                      [32]
# │    └─Darknet53Conv2d (conv1): 2-2                [1, 32, 256, 256]         [1, 64, 128, 128]         --                        --                        --                        True
# │    │    └─conv.weight                                                                                ├─18,432                  [64, 32, 3, 3]
# │    │    └─bn.weight                                                                                  ├─64                      [64]
# │    │    └─bn.bias                                                                                    └─64                      [64]
# │    │    └─Conv2d (conv): 3-3                     [1, 32, 256, 256]         [1, 64, 128, 128]         18,432                    [3, 3]                    301,989,888               True
# │    │    │    └─weight                                                                                └─18,432                  [32, 64, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-4                  [1, 64, 128, 128]         [1, 64, 128, 128]         128                       --                        128                       True
# │    │    │    └─weight                                                                                ├─64                      [64]
# │    │    │    └─bias                                                                                  └─64                      [64]
# │    └─Darknet53Block (stage1_block1): 2-3         [1, 64, 128, 128]         [1, 64, 128, 128]         --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─2,048                   [32, 64, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─32                      [32]
# │    │    └─conv1x1.bn.bias                                                                            ├─32                      [32]
# │    │    └─conv3x3.conv.weight                                                                        ├─18,432                  [64, 32, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─64                      [64]
# │    │    └─conv3x3.bn.bias                                                                            └─64                      [64]
# │    │    └─Darknet53Conv2d (conv1x1): 3-5         [1, 64, 128, 128]         [1, 32, 128, 128]         --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─2,048                   [32, 64, 1, 1]
# │    │    │    └─bn.weight                                                                             ├─32                      [32]
# │    │    │    └─bn.bias                                                                               └─32                      [32]
# │    │    │    └─Conv2d (conv): 4-1                [1, 64, 128, 128]         [1, 32, 128, 128]         2,048                     [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─2,048                   [64, 32, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-2             [1, 32, 128, 128]         [1, 32, 128, 128]         64                        --                        64                        True
# │    │    │    │    └─weight                                                                           ├─32                      [32]
# │    │    │    │    └─bias                                                                             └─32                      [32]
# │    │    └─Darknet53Conv2d (conv3x3): 3-6         [1, 32, 128, 128]         [1, 64, 128, 128]         --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─18,432                  [64, 32, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─64                      [64]
# │    │    │    └─bn.bias                                                                               └─64                      [64]
# │    │    │    └─Conv2d (conv): 4-3                [1, 32, 128, 128]         [1, 64, 128, 128]         18,432                    [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─18,432                  [32, 64, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-4             [1, 64, 128, 128]         [1, 64, 128, 128]         128                       --                        128                       True
# │    │    │    │    └─weight                                                                           ├─64                      [64]
# │    │    │    │    └─bias                                                                             └─64                      [64]
# │    └─Darknet53Conv2d (conv2): 2-4                [1, 64, 128, 128]         [1, 128, 64, 64]          --                        --                        --                        True
# │    │    └─conv.weight                                                                                ├─73,728                  [128, 64, 3, 3]
# │    │    └─bn.weight                                                                                  ├─128                     [128]
# │    │    └─bn.bias                                                                                    └─128                     [128]
# │    │    └─Conv2d (conv): 3-7                     [1, 64, 128, 128]         [1, 128, 64, 64]          73,728                    [3, 3]                    301,989,888               True
# │    │    │    └─weight                                                                                └─73,728                  [64, 128, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-8                  [1, 128, 64, 64]          [1, 128, 64, 64]          256                       --                        256                       True
# │    │    │    └─weight                                                                                ├─128                     [128]
# │    │    │    └─bias                                                                                  └─128                     [128]
# │    └─Darknet53Block (stage2_block1): 2-5         [1, 128, 64, 64]          [1, 128, 64, 64]          --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─8,192                   [64, 128, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─64                      [64]
# │    │    └─conv1x1.bn.bias                                                                            ├─64                      [64]
# │    │    └─conv3x3.conv.weight                                                                        ├─73,728                  [128, 64, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─128                     [128]
# │    │    └─conv3x3.bn.bias                                                                            └─128                     [128]
# │    │    └─Darknet53Conv2d (conv1x1): 3-9         [1, 128, 64, 64]          [1, 64, 64, 64]           --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─8,192                   [64, 128, 1, 1]
# │    │    │    └─bn.weight                                                                             ├─64                      [64]
# │    │    │    └─bn.bias                                                                               └─64                      [64]
# │    │    │    └─Conv2d (conv): 4-5                [1, 128, 64, 64]          [1, 64, 64, 64]           8,192                     [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─8,192                   [128, 64, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-6             [1, 64, 64, 64]           [1, 64, 64, 64]           128                       --                        128                       True
# │    │    │    │    └─weight                                                                           ├─64                      [64]
# │    │    │    │    └─bias                                                                             └─64                      [64]
# │    │    └─Darknet53Conv2d (conv3x3): 3-10        [1, 64, 64, 64]           [1, 128, 64, 64]          --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─73,728                  [128, 64, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─128                     [128]
# │    │    │    └─bn.bias                                                                               └─128                     [128]
# │    │    │    └─Conv2d (conv): 4-7                [1, 64, 64, 64]           [1, 128, 64, 64]          73,728                    [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─73,728                  [64, 128, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-8             [1, 128, 64, 64]          [1, 128, 64, 64]          256                       --                        256                       True
# │    │    │    │    └─weight                                                                           ├─128                     [128]
# │    │    │    │    └─bias                                                                             └─128                     [128]
# │    └─Darknet53Block (stage2_block2): 2-6         [1, 128, 64, 64]          [1, 128, 64, 64]          --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─8,192                   [64, 128, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─64                      [64]
# │    │    └─conv1x1.bn.bias                                                                            ├─64                      [64]
# │    │    └─conv3x3.conv.weight                                                                        ├─73,728                  [128, 64, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─128                     [128]
# │    │    └─conv3x3.bn.bias                                                                            └─128                     [128]
# │    │    └─Darknet53Conv2d (conv1x1): 3-11        [1, 128, 64, 64]          [1, 64, 64, 64]           --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─8,192                   [64, 128, 1, 1]
# │    │    │    └─bn.weight                                                                             ├─64                      [64]
# │    │    │    └─bn.bias                                                                               └─64                      [64]
# │    │    │    └─Conv2d (conv): 4-9                [1, 128, 64, 64]          [1, 64, 64, 64]           8,192                     [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─8,192                   [128, 64, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-10            [1, 64, 64, 64]           [1, 64, 64, 64]           128                       --                        128                       True
# │    │    │    │    └─weight                                                                           ├─64                      [64]
# │    │    │    │    └─bias                                                                             └─64                      [64]
# │    │    └─Darknet53Conv2d (conv3x3): 3-12        [1, 64, 64, 64]           [1, 128, 64, 64]          --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─73,728                  [128, 64, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─128                     [128]
# │    │    │    └─bn.bias                                                                               └─128                     [128]
# │    │    │    └─Conv2d (conv): 4-11               [1, 64, 64, 64]           [1, 128, 64, 64]          73,728                    [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─73,728                  [64, 128, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-12            [1, 128, 64, 64]          [1, 128, 64, 64]          256                       --                        256                       True
# │    │    │    │    └─weight                                                                           ├─128                     [128]
# │    │    │    │    └─bias                                                                             └─128                     [128]
# │    └─Darknet53Conv2d (conv3): 2-7                [1, 128, 64, 64]          [1, 256, 32, 32]          --                        --                        --                        True
# │    │    └─conv.weight                                                                                ├─294,912                 [256, 128, 3, 3]
# │    │    └─bn.weight                                                                                  ├─256                     [256]
# │    │    └─bn.bias                                                                                    └─256                     [256]
# │    │    └─Conv2d (conv): 3-13                    [1, 128, 64, 64]          [1, 256, 32, 32]          294,912                   [3, 3]                    301,989,888               True
# │    │    │    └─weight                                                                                └─294,912                 [128, 256, 3, 3]
# │    │    └─BatchNorm2d (bn): 3-14                 [1, 256, 32, 32]          [1, 256, 32, 32]          512                       --                        512                       True
# │    │    │    └─weight                                                                                ├─256                     [256]
# │    │    │    └─bias                                                                                  └─256                     [256]
# │    └─Darknet53Block (stage3_block1): 2-8         [1, 256, 32, 32]          [1, 256, 32, 32]          --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─32,768                  [128, 256, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─128                     [128]
# │    │    └─conv1x1.bn.bias                                                                            ├─128                     [128]
# │    │    └─conv3x3.conv.weight                                                                        ├─294,912                 [256, 128, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─256                     [256]
# │    │    └─conv3x3.bn.bias                                                                            └─256                     [256]
# │    │    └─Darknet53Conv2d (conv1x1): 3-15        [1, 256, 32, 32]          [1, 128, 32, 32]          --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─32,768                  [128, 256, 1, 1]
# │    │    │    └─bn.weight                                                                             ├─128                     [128]
# │    │    │    └─bn.bias                                                                               └─128                     [128]
# │    │    │    └─Conv2d (conv): 4-13               [1, 256, 32, 32]          [1, 128, 32, 32]          32,768                    [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─32,768                  [256, 128, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-14            [1, 128, 32, 32]          [1, 128, 32, 32]          256                       --                        256                       True
# │    │    │    │    └─weight                                                                           ├─128                     [128]
# │    │    │    │    └─bias                                                                             └─128                     [128]
# │    │    └─Darknet53Conv2d (conv3x3): 3-16        [1, 128, 32, 32]          [1, 256, 32, 32]          --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─294,912                 [256, 128, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─256                     [256]
# │    │    │    └─bn.bias                                                                               └─256                     [256]
# │    │    │    └─Conv2d (conv): 4-15               [1, 128, 32, 32]          [1, 256, 32, 32]          294,912                   [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─294,912                 [128, 256, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-16            [1, 256, 32, 32]          [1, 256, 32, 32]          512                       --                        512                       True
# │    │    │    │    └─weight                                                                           ├─256                     [256]
# │    │    │    │    └─bias                                                                             └─256                     [256]
# │    └─Darknet53Block (stage3_block2): 2-9         [1, 256, 32, 32]          [1, 256, 32, 32]          --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─32,768                  [128, 256, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─128                     [128]
# │    │    └─conv1x1.bn.bias                                                                            ├─128                     [128]
# │    │    └─conv3x3.conv.weight                                                                        ├─294,912                 [256, 128, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─256                     [256]
# │    │    └─conv3x3.bn.bias                                                                            └─256                     [256]
# │    │    └─Darknet53Conv2d (conv1x1): 3-17        [1, 256, 32, 32]          [1, 128, 32, 32]          --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─32,768                  [128, 256, 1, 1]
# │    │    │    └─bn.weight                                                                             ├─128                     [128]
# │    │    │    └─bn.bias                                                                               └─128                     [128]
# │    │    │    └─Conv2d (conv): 4-17               [1, 256, 32, 32]          [1, 128, 32, 32]          32,768                    [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─32,768                  [256, 128, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-18            [1, 128, 32, 32]          [1, 128, 32, 32]          256                       --                        256                       True
# │    │    │    │    └─weight                                                                           ├─128                     [128]
# │    │    │    │    └─bias                                                                             └─128                     [128]
# │    │    └─Darknet53Conv2d (conv3x3): 3-18        [1, 128, 32, 32]          [1, 256, 32, 32]          --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─294,912                 [256, 128, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─256                     [256]
# │    │    │    └─bn.bias                                                                               └─256                     [256]
# │    │    │    └─Conv2d (conv): 4-19               [1, 128, 32, 32]          [1, 256, 32, 32]          294,912                   [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─294,912                 [128, 256, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-20            [1, 256, 32, 32]          [1, 256, 32, 32]          512                       --                        512                       True
# │    │    │    │    └─weight                                                                           ├─256                     [256]
# │    │    │    │    └─bias                                                                             └─256                     [256]
# │    └─Darknet53Block (stage3_block3): 2-10        [1, 256, 32, 32]          [1, 256, 32, 32]          --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─32,768                  [128, 256, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─128                     [128]
# │    │    └─conv1x1.bn.bias                                                                            ├─128                     [128]
# │    │    └─conv3x3.conv.weight                                                                        ├─294,912                 [256, 128, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─256                     [256]
# ...
# │    │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    │    └─Conv2d (conv): 4-77               [1, 1024, 8, 8]           [1, 512, 8, 8]            524,288                   [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─524,288                 [1024, 512, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-78            [1, 512, 8, 8]            [1, 512, 8, 8]            1,024                     --                        1,024                     True
# │    │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    │    └─bias                                                                             └─512                     [512]
# │    │    └─Darknet53Conv2d (conv3x3): 3-52        [1, 512, 8, 8]            [1, 1024, 8, 8]           --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    │    │    └─bn.bias                                                                               └─1,024                   [1024]
# │    │    │    └─Conv2d (conv): 4-79               [1, 512, 8, 8]            [1, 1024, 8, 8]           4,718,592                 [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-80            [1, 1024, 8, 8]           [1, 1024, 8, 8]           2,048                     --                        2,048                     True
# │    │    │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    │    │    └─bias                                                                             └─1,024                   [1024]
# │    └─Darknet53Block (stage5_block2): 2-27        [1, 1024, 8, 8]           [1, 1024, 8, 8]           --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─524,288                 [512, 1024, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─512                     [512]
# │    │    └─conv1x1.bn.bias                                                                            ├─512                     [512]
# │    │    └─conv3x3.conv.weight                                                                        ├─4,718,592               [1024, 512, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─1,024                   [1024]
# │    │    └─conv3x3.bn.bias                                                                            └─1,024                   [1024]
# │    │    └─Darknet53Conv2d (conv1x1): 3-53        [1, 1024, 8, 8]           [1, 512, 8, 8]            --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─524,288                 [512, 1024, 1, 1]
# │    │    │    └─bn.weight                                                                             ├─512                     [512]
# │    │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    │    └─Conv2d (conv): 4-81               [1, 1024, 8, 8]           [1, 512, 8, 8]            524,288                   [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─524,288                 [1024, 512, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-82            [1, 512, 8, 8]            [1, 512, 8, 8]            1,024                     --                        1,024                     True
# │    │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    │    └─bias                                                                             └─512                     [512]
# │    │    └─Darknet53Conv2d (conv3x3): 3-54        [1, 512, 8, 8]            [1, 1024, 8, 8]           --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    │    │    └─bn.bias                                                                               └─1,024                   [1024]
# │    │    │    └─Conv2d (conv): 4-83               [1, 512, 8, 8]            [1, 1024, 8, 8]           4,718,592                 [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-84            [1, 1024, 8, 8]           [1, 1024, 8, 8]           2,048                     --                        2,048                     True
# │    │    │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    │    │    └─bias                                                                             └─1,024                   [1024]
# │    └─Darknet53Block (stage5_block3): 2-28        [1, 1024, 8, 8]           [1, 1024, 8, 8]           --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─524,288                 [512, 1024, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─512                     [512]
# │    │    └─conv1x1.bn.bias                                                                            ├─512                     [512]
# │    │    └─conv3x3.conv.weight                                                                        ├─4,718,592               [1024, 512, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─1,024                   [1024]
# │    │    └─conv3x3.bn.bias                                                                            └─1,024                   [1024]
# │    │    └─Darknet53Conv2d (conv1x1): 3-55        [1, 1024, 8, 8]           [1, 512, 8, 8]            --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─524,288                 [512, 1024, 1, 1]
# │    │    │    └─bn.weight                                                                             ├─512                     [512]
# │    │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    │    └─Conv2d (conv): 4-85               [1, 1024, 8, 8]           [1, 512, 8, 8]            524,288                   [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─524,288                 [1024, 512, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-86            [1, 512, 8, 8]            [1, 512, 8, 8]            1,024                     --                        1,024                     True
# │    │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    │    └─bias                                                                             └─512                     [512]
# │    │    └─Darknet53Conv2d (conv3x3): 3-56        [1, 512, 8, 8]            [1, 1024, 8, 8]           --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    │    │    └─bn.bias                                                                               └─1,024                   [1024]
# │    │    │    └─Conv2d (conv): 4-87               [1, 512, 8, 8]            [1, 1024, 8, 8]           4,718,592                 [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-88            [1, 1024, 8, 8]           [1, 1024, 8, 8]           2,048                     --                        2,048                     True
# │    │    │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    │    │    └─bias                                                                             └─1,024                   [1024]
# │    └─Darknet53Block (stage5_block4): 2-29        [1, 1024, 8, 8]           [1, 1024, 8, 8]           --                        --                        --                        True
# │    │    └─conv1x1.conv.weight                                                                        ├─524,288                 [512, 1024, 1, 1]
# │    │    └─conv1x1.bn.weight                                                                          ├─512                     [512]
# │    │    └─conv1x1.bn.bias                                                                            ├─512                     [512]
# │    │    └─conv3x3.conv.weight                                                                        ├─4,718,592               [1024, 512, 3, 3]
# │    │    └─conv3x3.bn.weight                                                                          ├─1,024                   [1024]
# │    │    └─conv3x3.bn.bias                                                                            └─1,024                   [1024]
# │    │    └─Darknet53Conv2d (conv1x1): 3-57        [1, 1024, 8, 8]           [1, 512, 8, 8]            --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─524,288                 [512, 1024, 1, 1]
# │    │    │    └─bn.weight                                                                             ├─512                     [512]
# │    │    │    └─bn.bias                                                                               └─512                     [512]
# │    │    │    └─Conv2d (conv): 4-89               [1, 1024, 8, 8]           [1, 512, 8, 8]            524,288                   [1, 1]                    33,554,432                True
# │    │    │    │    └─weight                                                                           └─524,288                 [1024, 512, 1, 1]
# │    │    │    └─BatchNorm2d (bn): 4-90            [1, 512, 8, 8]            [1, 512, 8, 8]            1,024                     --                        1,024                     True
# │    │    │    │    └─weight                                                                           ├─512                     [512]
# │    │    │    │    └─bias                                                                             └─512                     [512]
# │    │    └─Darknet53Conv2d (conv3x3): 3-58        [1, 512, 8, 8]            [1, 1024, 8, 8]           --                        --                        --                        True
# │    │    │    └─conv.weight                                                                           ├─4,718,592               [1024, 512, 3, 3]
# │    │    │    └─bn.weight                                                                             ├─1,024                   [1024]
# │    │    │    └─bn.bias                                                                               └─1,024                   [1024]
# │    │    │    └─Conv2d (conv): 4-91               [1, 512, 8, 8]            [1, 1024, 8, 8]           4,718,592                 [3, 3]                    301,989,888               True
# │    │    │    │    └─weight                                                                           └─4,718,592               [512, 1024, 3, 3]
# │    │    │    └─BatchNorm2d (bn): 4-92            [1, 1024, 8, 8]           [1, 1024, 8, 8]           2,048                     --                        2,048                     True
# │    │    │    │    └─weight                                                                           ├─1,024                   [1024]
# │    │    │    │    └─bias                                                                             └─1,024                   [1024]
# ├─Sequential (head): 1-2                           [1, 1024, 8, 8]           [1, 1000]                 --                        --                        --                        True
# │    └─2.weight                                                                                        ├─1,024,000               [1000, 1024]
# │    └─2.bias                                                                                          └─1,000                   [1000]
# │    └─AdaptiveAvgPool2d (0): 2-30                 [1, 1024, 8, 8]           [1, 1024, 1, 1]           --                        --                        --                        --
# │    └─Flatten (1): 2-31                           [1, 1024, 1, 1]           [1, 1024]                 --                        --                        --                        --
# │    └─Linear (2): 2-32                            [1, 1024]                 [1, 1000]                 1,025,000                 --                        1,025,000                 True
# │    │    └─weight                                                                                     ├─1,024,000               [1024, 1000]
# │    │    └─bias                                                                                       └─1,000                   [1000]
# ========================================================================================================================================================================================================
# Total params: 41,609,928
# Trainable params: 41,609,928
# Non-trainable params: 0
# Total mult-adds (G): 9.29
# ========================================================================================================================================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 198.19
# Params size (MB): 166.44
# Estimated Total Size (MB): 365.42
# ========================================================================================================================================================================================================

# %%
writer = SummaryWriter()
imgs = torch.randn(batch_size, 3, img_h, img_w)
targets = torch.randint(0, n_class, (batch_size,))
writer.add_graph(model, [imgs, targets])
writer.close()

# %%
logits, loss = model(imgs, targets)
print(logits.shape)
print(loss.shape)
# Out:
# torch.Size([1, 1000])
# torch.Size([])

# %% [markdown]
# ## Inspect state_dict

# %%
import tempfile

# Save state_dict as a temporary file
with tempfile.NamedTemporaryFile(suffix='.pth') as temp_file:
    torch.save(model.state_dict(), temp_file.name)
    state_dict = torch.load(temp_file.name)

# Print the keys of the state_dict
for key in state_dict.keys():
    print(key)
# Out:
# backbone.conv0.conv.weight
# backbone.conv0.bn.weight
# backbone.conv0.bn.bias
# backbone.conv0.bn.running_mean
# backbone.conv0.bn.running_var
# backbone.conv0.bn.num_batches_tracked
# backbone.conv1.conv.weight
# backbone.conv1.bn.weight
# backbone.conv1.bn.bias
# backbone.conv1.bn.running_mean
# backbone.conv1.bn.running_var
# backbone.conv1.bn.num_batches_tracked
# backbone.stage1_block1.conv1x1.conv.weight
# backbone.stage1_block1.conv1x1.bn.weight
# backbone.stage1_block1.conv1x1.bn.bias
# backbone.stage1_block1.conv1x1.bn.running_mean
# backbone.stage1_block1.conv1x1.bn.running_var
# backbone.stage1_block1.conv1x1.bn.num_batches_tracked
# backbone.stage1_block1.conv3x3.conv.weight
# backbone.stage1_block1.conv3x3.bn.weight
# backbone.stage1_block1.conv3x3.bn.bias
# backbone.stage1_block1.conv3x3.bn.running_mean
# backbone.stage1_block1.conv3x3.bn.running_var
# backbone.stage1_block1.conv3x3.bn.num_batches_tracked
# backbone.conv2.conv.weight
# backbone.conv2.bn.weight
# backbone.conv2.bn.bias
# backbone.conv2.bn.running_mean
# backbone.conv2.bn.running_var
# backbone.conv2.bn.num_batches_tracked
# backbone.stage2_block1.conv1x1.conv.weight
# backbone.stage2_block1.conv1x1.bn.weight
# backbone.stage2_block1.conv1x1.bn.bias
# backbone.stage2_block1.conv1x1.bn.running_mean
# backbone.stage2_block1.conv1x1.bn.running_var
# backbone.stage2_block1.conv1x1.bn.num_batches_tracked
# backbone.stage2_block1.conv3x3.conv.weight
# backbone.stage2_block1.conv3x3.bn.weight
# backbone.stage2_block1.conv3x3.bn.bias
# backbone.stage2_block1.conv3x3.bn.running_mean
# backbone.stage2_block1.conv3x3.bn.running_var
# backbone.stage2_block1.conv3x3.bn.num_batches_tracked
# backbone.stage2_block2.conv1x1.conv.weight
# backbone.stage2_block2.conv1x1.bn.weight
# backbone.stage2_block2.conv1x1.bn.bias
# backbone.stage2_block2.conv1x1.bn.running_mean
# backbone.stage2_block2.conv1x1.bn.running_var
# backbone.stage2_block2.conv1x1.bn.num_batches_tracked
# backbone.stage2_block2.conv3x3.conv.weight
# backbone.stage2_block2.conv3x3.bn.weight
# backbone.stage2_block2.conv3x3.bn.bias
# backbone.stage2_block2.conv3x3.bn.running_mean
# backbone.stage2_block2.conv3x3.bn.running_var
# backbone.stage2_block2.conv3x3.bn.num_batches_tracked
# backbone.conv3.conv.weight
# backbone.conv3.bn.weight
# backbone.conv3.bn.bias
# backbone.conv3.bn.running_mean
# backbone.conv3.bn.running_var
# backbone.conv3.bn.num_batches_tracked
# backbone.stage3_block1.conv1x1.conv.weight
# backbone.stage3_block1.conv1x1.bn.weight
# backbone.stage3_block1.conv1x1.bn.bias
# backbone.stage3_block1.conv1x1.bn.running_mean
# backbone.stage3_block1.conv1x1.bn.running_var
# backbone.stage3_block1.conv1x1.bn.num_batches_tracked
# backbone.stage3_block1.conv3x3.conv.weight
# backbone.stage3_block1.conv3x3.bn.weight
# backbone.stage3_block1.conv3x3.bn.bias
# backbone.stage3_block1.conv3x3.bn.running_mean
# backbone.stage3_block1.conv3x3.bn.running_var
# backbone.stage3_block1.conv3x3.bn.num_batches_tracked
# backbone.stage3_block2.conv1x1.conv.weight
# backbone.stage3_block2.conv1x1.bn.weight
# backbone.stage3_block2.conv1x1.bn.bias
# backbone.stage3_block2.conv1x1.bn.running_mean
# backbone.stage3_block2.conv1x1.bn.running_var
# backbone.stage3_block2.conv1x1.bn.num_batches_tracked
# backbone.stage3_block2.conv3x3.conv.weight
# backbone.stage3_block2.conv3x3.bn.weight
# backbone.stage3_block2.conv3x3.bn.bias
# backbone.stage3_block2.conv3x3.bn.running_mean
# backbone.stage3_block2.conv3x3.bn.running_var
# backbone.stage3_block2.conv3x3.bn.num_batches_tracked
# backbone.stage3_block3.conv1x1.conv.weight
# backbone.stage3_block3.conv1x1.bn.weight
# backbone.stage3_block3.conv1x1.bn.bias
# backbone.stage3_block3.conv1x1.bn.running_mean
# backbone.stage3_block3.conv1x1.bn.running_var
# backbone.stage3_block3.conv1x1.bn.num_batches_tracked
# backbone.stage3_block3.conv3x3.conv.weight
# backbone.stage3_block3.conv3x3.bn.weight
# backbone.stage3_block3.conv3x3.bn.bias
# backbone.stage3_block3.conv3x3.bn.running_mean
# backbone.stage3_block3.conv3x3.bn.running_var
# backbone.stage3_block3.conv3x3.bn.num_batches_tracked
# backbone.stage3_block4.conv1x1.conv.weight
# backbone.stage3_block4.conv1x1.bn.weight
# backbone.stage3_block4.conv1x1.bn.bias
# backbone.stage3_block4.conv1x1.bn.running_mean
# backbone.stage3_block4.conv1x1.bn.running_var
# backbone.stage3_block4.conv1x1.bn.num_batches_tracked
# backbone.stage3_block4.conv3x3.conv.weight
# backbone.stage3_block4.conv3x3.bn.weight
# backbone.stage3_block4.conv3x3.bn.bias
# backbone.stage3_block4.conv3x3.bn.running_mean
# backbone.stage3_block4.conv3x3.bn.running_var
# backbone.stage3_block4.conv3x3.bn.num_batches_tracked
# backbone.stage3_block5.conv1x1.conv.weight
# backbone.stage3_block5.conv1x1.bn.weight
# backbone.stage3_block5.conv1x1.bn.bias
# backbone.stage3_block5.conv1x1.bn.running_mean
# backbone.stage3_block5.conv1x1.bn.running_var
# backbone.stage3_block5.conv1x1.bn.num_batches_tracked
# backbone.stage3_block5.conv3x3.conv.weight
# backbone.stage3_block5.conv3x3.bn.weight
# backbone.stage3_block5.conv3x3.bn.bias
# backbone.stage3_block5.conv3x3.bn.running_mean
# backbone.stage3_block5.conv3x3.bn.running_var
# backbone.stage3_block5.conv3x3.bn.num_batches_tracked
# backbone.stage3_block6.conv1x1.conv.weight
# backbone.stage3_block6.conv1x1.bn.weight
# backbone.stage3_block6.conv1x1.bn.bias
# backbone.stage3_block6.conv1x1.bn.running_mean
# backbone.stage3_block6.conv1x1.bn.running_var
# backbone.stage3_block6.conv1x1.bn.num_batches_tracked
# backbone.stage3_block6.conv3x3.conv.weight
# backbone.stage3_block6.conv3x3.bn.weight
# backbone.stage3_block6.conv3x3.bn.bias
# backbone.stage3_block6.conv3x3.bn.running_mean
# backbone.stage3_block6.conv3x3.bn.running_var
# backbone.stage3_block6.conv3x3.bn.num_batches_tracked
# backbone.stage3_block7.conv1x1.conv.weight
# backbone.stage3_block7.conv1x1.bn.weight
# backbone.stage3_block7.conv1x1.bn.bias
# backbone.stage3_block7.conv1x1.bn.running_mean
# backbone.stage3_block7.conv1x1.bn.running_var
# backbone.stage3_block7.conv1x1.bn.num_batches_tracked
# backbone.stage3_block7.conv3x3.conv.weight
# backbone.stage3_block7.conv3x3.bn.weight
# backbone.stage3_block7.conv3x3.bn.bias
# backbone.stage3_block7.conv3x3.bn.running_mean
# backbone.stage3_block7.conv3x3.bn.running_var
# backbone.stage3_block7.conv3x3.bn.num_batches_tracked
# backbone.stage3_block8.conv1x1.conv.weight
# backbone.stage3_block8.conv1x1.bn.weight
# backbone.stage3_block8.conv1x1.bn.bias
# backbone.stage3_block8.conv1x1.bn.running_mean
# backbone.stage3_block8.conv1x1.bn.running_var
# backbone.stage3_block8.conv1x1.bn.num_batches_tracked
# backbone.stage3_block8.conv3x3.conv.weight
# backbone.stage3_block8.conv3x3.bn.weight
# backbone.stage3_block8.conv3x3.bn.bias
# backbone.stage3_block8.conv3x3.bn.running_mean
# backbone.stage3_block8.conv3x3.bn.running_var
# backbone.stage3_block8.conv3x3.bn.num_batches_tracked
# backbone.conv4.conv.weight
# backbone.conv4.bn.weight
# backbone.conv4.bn.bias
# backbone.conv4.bn.running_mean
# backbone.conv4.bn.running_var
# backbone.conv4.bn.num_batches_tracked
# backbone.stage4_block1.conv1x1.conv.weight
# backbone.stage4_block1.conv1x1.bn.weight
# backbone.stage4_block1.conv1x1.bn.bias
# backbone.stage4_block1.conv1x1.bn.running_mean
# backbone.stage4_block1.conv1x1.bn.running_var
# backbone.stage4_block1.conv1x1.bn.num_batches_tracked
# backbone.stage4_block1.conv3x3.conv.weight
# backbone.stage4_block1.conv3x3.bn.weight
# backbone.stage4_block1.conv3x3.bn.bias
# backbone.stage4_block1.conv3x3.bn.running_mean
# backbone.stage4_block1.conv3x3.bn.running_var
# backbone.stage4_block1.conv3x3.bn.num_batches_tracked
# backbone.stage4_block2.conv1x1.conv.weight
# backbone.stage4_block2.conv1x1.bn.weight
# backbone.stage4_block2.conv1x1.bn.bias
# backbone.stage4_block2.conv1x1.bn.running_mean
# backbone.stage4_block2.conv1x1.bn.running_var
# backbone.stage4_block2.conv1x1.bn.num_batches_tracked
# backbone.stage4_block2.conv3x3.conv.weight
# backbone.stage4_block2.conv3x3.bn.weight
# backbone.stage4_block2.conv3x3.bn.bias
# backbone.stage4_block2.conv3x3.bn.running_mean
# backbone.stage4_block2.conv3x3.bn.running_var
# backbone.stage4_block2.conv3x3.bn.num_batches_tracked
# backbone.stage4_block3.conv1x1.conv.weight
# backbone.stage4_block3.conv1x1.bn.weight
# backbone.stage4_block3.conv1x1.bn.bias
# backbone.stage4_block3.conv1x1.bn.running_mean
# backbone.stage4_block3.conv1x1.bn.running_var
# backbone.stage4_block3.conv1x1.bn.num_batches_tracked
# backbone.stage4_block3.conv3x3.conv.weight
# backbone.stage4_block3.conv3x3.bn.weight
# backbone.stage4_block3.conv3x3.bn.bias
# backbone.stage4_block3.conv3x3.bn.running_mean
# backbone.stage4_block3.conv3x3.bn.running_var
# backbone.stage4_block3.conv3x3.bn.num_batches_tracked
# backbone.stage4_block4.conv1x1.conv.weight
# backbone.stage4_block4.conv1x1.bn.weight
# backbone.stage4_block4.conv1x1.bn.bias
# backbone.stage4_block4.conv1x1.bn.running_mean
# backbone.stage4_block4.conv1x1.bn.running_var
# backbone.stage4_block4.conv1x1.bn.num_batches_tracked
# backbone.stage4_block4.conv3x3.conv.weight
# backbone.stage4_block4.conv3x3.bn.weight
# backbone.stage4_block4.conv3x3.bn.bias
# backbone.stage4_block4.conv3x3.bn.running_mean
# backbone.stage4_block4.conv3x3.bn.running_var
# backbone.stage4_block4.conv3x3.bn.num_batches_tracked
# backbone.stage4_block5.conv1x1.conv.weight
# backbone.stage4_block5.conv1x1.bn.weight
# backbone.stage4_block5.conv1x1.bn.bias
# backbone.stage4_block5.conv1x1.bn.running_mean
# backbone.stage4_block5.conv1x1.bn.running_var
# backbone.stage4_block5.conv1x1.bn.num_batches_tracked
# backbone.stage4_block5.conv3x3.conv.weight
# backbone.stage4_block5.conv3x3.bn.weight
# backbone.stage4_block5.conv3x3.bn.bias
# backbone.stage4_block5.conv3x3.bn.running_mean
# backbone.stage4_block5.conv3x3.bn.running_var
# backbone.stage4_block5.conv3x3.bn.num_batches_tracked
# backbone.stage4_block6.conv1x1.conv.weight
# backbone.stage4_block6.conv1x1.bn.weight
# backbone.stage4_block6.conv1x1.bn.bias
# backbone.stage4_block6.conv1x1.bn.running_mean
# backbone.stage4_block6.conv1x1.bn.running_var
# backbone.stage4_block6.conv1x1.bn.num_batches_tracked
# backbone.stage4_block6.conv3x3.conv.weight
# backbone.stage4_block6.conv3x3.bn.weight
# backbone.stage4_block6.conv3x3.bn.bias
# backbone.stage4_block6.conv3x3.bn.running_mean
# backbone.stage4_block6.conv3x3.bn.running_var
# backbone.stage4_block6.conv3x3.bn.num_batches_tracked
# backbone.stage4_block7.conv1x1.conv.weight
# backbone.stage4_block7.conv1x1.bn.weight
# backbone.stage4_block7.conv1x1.bn.bias
# backbone.stage4_block7.conv1x1.bn.running_mean
# backbone.stage4_block7.conv1x1.bn.running_var
# backbone.stage4_block7.conv1x1.bn.num_batches_tracked
# backbone.stage4_block7.conv3x3.conv.weight
# backbone.stage4_block7.conv3x3.bn.weight
# backbone.stage4_block7.conv3x3.bn.bias
# backbone.stage4_block7.conv3x3.bn.running_mean
# backbone.stage4_block7.conv3x3.bn.running_var
# backbone.stage4_block7.conv3x3.bn.num_batches_tracked
# backbone.stage4_block8.conv1x1.conv.weight
# backbone.stage4_block8.conv1x1.bn.weight
# backbone.stage4_block8.conv1x1.bn.bias
# backbone.stage4_block8.conv1x1.bn.running_mean
# backbone.stage4_block8.conv1x1.bn.running_var
# backbone.stage4_block8.conv1x1.bn.num_batches_tracked
# backbone.stage4_block8.conv3x3.conv.weight
# backbone.stage4_block8.conv3x3.bn.weight
# backbone.stage4_block8.conv3x3.bn.bias
# backbone.stage4_block8.conv3x3.bn.running_mean
# backbone.stage4_block8.conv3x3.bn.running_var
# backbone.stage4_block8.conv3x3.bn.num_batches_tracked
# backbone.conv5.conv.weight
# backbone.conv5.bn.weight
# backbone.conv5.bn.bias
# backbone.conv5.bn.running_mean
# backbone.conv5.bn.running_var
# backbone.conv5.bn.num_batches_tracked
# backbone.stage5_block1.conv1x1.conv.weight
# backbone.stage5_block1.conv1x1.bn.weight
# backbone.stage5_block1.conv1x1.bn.bias
# backbone.stage5_block1.conv1x1.bn.running_mean
# backbone.stage5_block1.conv1x1.bn.running_var
# backbone.stage5_block1.conv1x1.bn.num_batches_tracked
# backbone.stage5_block1.conv3x3.conv.weight
# backbone.stage5_block1.conv3x3.bn.weight
# backbone.stage5_block1.conv3x3.bn.bias
# backbone.stage5_block1.conv3x3.bn.running_mean
# backbone.stage5_block1.conv3x3.bn.running_var
# backbone.stage5_block1.conv3x3.bn.num_batches_tracked
# backbone.stage5_block2.conv1x1.conv.weight
# backbone.stage5_block2.conv1x1.bn.weight
# backbone.stage5_block2.conv1x1.bn.bias
# backbone.stage5_block2.conv1x1.bn.running_mean
# backbone.stage5_block2.conv1x1.bn.running_var
# backbone.stage5_block2.conv1x1.bn.num_batches_tracked
# backbone.stage5_block2.conv3x3.conv.weight
# backbone.stage5_block2.conv3x3.bn.weight
# backbone.stage5_block2.conv3x3.bn.bias
# backbone.stage5_block2.conv3x3.bn.running_mean
# backbone.stage5_block2.conv3x3.bn.running_var
# backbone.stage5_block2.conv3x3.bn.num_batches_tracked
# backbone.stage5_block3.conv1x1.conv.weight
# backbone.stage5_block3.conv1x1.bn.weight
# backbone.stage5_block3.conv1x1.bn.bias
# backbone.stage5_block3.conv1x1.bn.running_mean
# backbone.stage5_block3.conv1x1.bn.running_var
# backbone.stage5_block3.conv1x1.bn.num_batches_tracked
# backbone.stage5_block3.conv3x3.conv.weight
# backbone.stage5_block3.conv3x3.bn.weight
# backbone.stage5_block3.conv3x3.bn.bias
# backbone.stage5_block3.conv3x3.bn.running_mean
# backbone.stage5_block3.conv3x3.bn.running_var
# backbone.stage5_block3.conv3x3.bn.num_batches_tracked
# backbone.stage5_block4.conv1x1.conv.weight
# backbone.stage5_block4.conv1x1.bn.weight
# backbone.stage5_block4.conv1x1.bn.bias
# backbone.stage5_block4.conv1x1.bn.running_mean
# backbone.stage5_block4.conv1x1.bn.running_var
# backbone.stage5_block4.conv1x1.bn.num_batches_tracked
# backbone.stage5_block4.conv3x3.conv.weight
# backbone.stage5_block4.conv3x3.bn.weight
# backbone.stage5_block4.conv3x3.bn.bias
# backbone.stage5_block4.conv3x3.bn.running_mean
# backbone.stage5_block4.conv3x3.bn.running_var
# backbone.stage5_block4.conv3x3.bn.num_batches_tracked
# head.2.weight
# head.2.bias

# %% [markdown]
# ## Inspect gradients

# %%
class DebugDependencyDarknet53(Darknet53):
    """Darknet53 with dummy loss function for debugging dependencies."""
    def __init__(self, loss_img_idx, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.loss_img_idx = loss_img_idx

    def _compute_loss(self, logits: Tensor, targets: Tensor) -> Tensor:
        """
        Compute the dummy loss as sum of all outputs of img i.
        Args:
            logits (Tensor): size(N, n_class)
            targets (Tensor): size(N,)
        Returns:
            loss (Tensor): size(,)
        """
        return torch.sum(logits[self.loss_img_idx])

# %% [markdown]
# To verify no inadvertently mix information across the batch dimension, run the backward pass all the way to the input, and ensure that you get a non-zero gradient only on the i-th input.

# %%
batch_size = 5
X = torch.randn(batch_size, 3, img_h, img_w, requires_grad=True)
Y =  torch.randint(0, n_class, (batch_size,))

# %%
print("Setup:")
torch.manual_seed(1337);  # since kaiming_normal_ weight init is random
loss_img_idx = 2
debug_dependency_model = DebugDependencyDarknet53(loss_img_idx, model_config)
debug_dependency_model.eval()  # since batchnorm will mixed variables between images in a batch

optimizer_type = 'adam'
learning_rate = 3e-4
beta1 = 0.9
beta2 = 0.999
weight_decay = 5e-4
device_type = 'cpu'
use_fused = False
optimizer = debug_dependency_model.configure_optimizers(optimizer_type, learning_rate, (beta1, beta2), weight_decay, device_type, use_fused)

print("\n\nForward pass:")
logits, loss = debug_dependency_model(X, Y)
print(f"{logits.shape=}")
print(f"{loss=}")

print("\n\nBackward pass & Gradients of X::")
optimizer.zero_grad(set_to_none=True)
X.grad = None  # zero out X gradients
loss.backward()

print(f"{X.grad.shape=}")
for idx_img in range(batch_size):
    print(f"Zero gradient of {idx_img}'th img: {torch.all(X.grad[idx_img]==0)}")

print("\n\nOptimizer step:")
optimizer.step()
print(f"Loss after optimized: {debug_dependency_model(X, Y)[1]}")
# Out:
# Setup:
# number of parameters: 41.61M
# num decayed parameter tensors: 53, with 41,573,216 parameters
# num non-decayed parameter tensors: 105, with 36,712 parameters
# using fused Adam: False
#
#
# Forward pass:
# logits.shape=torch.Size([5, 1000])
# loss=tensor(-5807.6699, grad_fn=<SumBackward0>)
#
#
# Backward pass & Gradients of X::
# X.grad.shape=torch.Size([5, 3, 256, 256])
# Zero gradient of 0'th img: True
# Zero gradient of 1'th img: True
# Zero gradient of 2'th img: False
# Zero gradient of 3'th img: True
# Zero gradient of 4'th img: True
#
#
# Optimizer step:
# Loss after optimized: -94209768.0

# %% [markdown]
# ## Inspect Results

# %%
# TODO
